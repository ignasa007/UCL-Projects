# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np

from q5_f import f, gradient
from bfgs import bfgs
from convergence_plots import error_convergence, gradient_norm_convergence, trajectories_convergence
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
xs, errors = bfgs(
    x_0=np.array([[-8.],[-8.]]),
    tol=1e-60
)

error_convergence(errors, xlog=False, ylog=True, overlay_fit=True, ignore=2)
gradient_norm_convergence(xs, gradient, ylog=True, overlay_fit=True, ignore=2)
# trajectories_convergence(
#     xs, f, 
#     start_idx=0, middle_idx=20, end_idx=None,
#     xlims=((-8.5, 0.5),None), 
#     ylims=((-8.5, 0.5),None),
#     arrows=False
# )
# Out:
# After 159 iterations, x_min = [-0.0, -0.0], f(x_min) = 1.410572404651863e-81

# %%
from convergence_plots import quotient_convergence
quotient_convergence(errors, order=1)
